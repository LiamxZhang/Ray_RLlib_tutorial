# %% [markdown]
# # RLlib 的入门介绍
# 首先，为算法创建一个 config，它定义了 RL 环境以及其他所需的设置和参数。

# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.connectors.env_to_module import FlattenObservations

# Configure the algorithm.
config = (
    PPOConfig()
    .environment("Taxi-v3")
    .env_runners(
        num_env_runners=2,
        # Observations are discrete (ints) -> We need to flatten (one-hot) them.
        env_to_module_connector=lambda env: FlattenObservations(),
    )
    .evaluation(evaluation_num_env_runners=1)
)

# %% [markdown]
# 接下来，build 算法并 train 共五次迭代。一次训练迭代包括由 EnvRunner actor 并行、分布式地收集样本，然后对收集到的数据计算损失，以及模型更新步骤。

# %%
from pprint import pprint

# Build the algorithm.
algo = config.build_algo()

# Train it for 5 iterations ...
for _ in range(5):
    pprint(algo.train())
# Out:
# 2025-08-04 14:07:24,804	WARNING algorithm_config.py:4921 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2025-08-04 14:07:24,863 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: '2b5c199acc21edf6159dcd7201000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# [2025-08-04 14:07:24,919 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'def4c9ad70df94358b2df4ba01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# 2025-08-04 14:07:28,885	WARNING algorithm_config.py:4921 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# [2025-08-04 14:07:28,933 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'ec3043a45a664db9b7f2659e01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# 2025-08-04 14:07:32,614	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': <function <lambda> at 0x7feb32864790>,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': None,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Taxi-v3',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 1,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 5e-05,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-07-49',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -773.05},
#                  'env_reset_timer': np.float64(0.000485341006424278),
#                  'env_step_timer': np.float64(0.0001304065412204731),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00033065422243518745),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.2762463454181793e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.492639449152549e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.2511403629752603e-05),
#                                                                        'batch_individual_items': np.float64(3.262354267456604e-05),
#                                                                        'flatten_observations': np.float64(7.593317771149142e-05),
#                                                                        'numpy_to_tensor': np.float64(6.1276117058504e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(124.57306755942355),
#                  'env_to_module_sum_episodes_length_out': np.float64(124.57306755942355),
#                  'episode_duration_sec_mean': 0.3831005702028051,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 199.45,
#                  'episode_len_min': 189,
#                  'episode_return_max': -668.0,
#                  'episode_return_mean': -773.05,
#                  'episode_return_min': -884.0,
#                  'module_episode_return_mean': {'default_policy': -773.05},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.000837292532289122),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.00045176500558452234),
#                                                                        'listify_data_for_vector_env': np.float64(5.205928176773505e-05),
#                                                                        'normalize_and_clip_actions': np.float64(4.7039282910808605e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.1599481718259625e-06),
#                                                                        'tensor_to_numpy': np.float64(9.077879550389647e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.7895324704922617e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 4000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 4000.0},
#                  'num_env_steps_sampled': 4000.0,
#                  'num_env_steps_sampled_lifetime': 4000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(512.1369026141531),
#                  'num_episodes': 20.0,
#                  'num_episodes_lifetime': 20.0,
#                  'num_module_steps_sampled': {'default_policy': 4000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 4000.0},
#                  'rlmodule_inference_timer': np.float64(0.00029300261240916374),
#                  'sample': np.float64(3.903082220000215),
#                  'weights_seq_no': 0.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 1,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.24530448601581156,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.10716797003988177,
#                                                                                   'add_observations_from_episodes_to_batch': 0.00031196896452456713,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.00854412594344467,
#                                                                                   'add_states_from_episodes_to_batch': 1.226295717060566e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.839307464659214e-05,
#                                                                                   'batch_individual_items': 0.08372482506092638,
#                                                                                   'general_advantage_estimation': 0.04464635800104588,
#                                                                                   'numpy_to_tensor': 0.00025411800015717745}}},
#                                   'learner_connector_sum_episodes_length_in': 4000,
#                                   'learner_connector_sum_episodes_length_out': 4021,
#                                   'num_env_steps_trained': 3791803,
#                                   'num_env_steps_trained_lifetime': 3791803,
#                                   'num_env_steps_trained_lifetime_throughput': 314577.44856316946,
#                                   'num_module_steps_trained': 120704,
#                                   'num_module_steps_trained_lifetime': 120704,
#                                   'num_module_steps_trained_lifetime_throughput': 10014.6834509276,
#                                   'num_module_steps_trained_throughput': 10015.164286111867,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 389895},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.20000000298023224,
#                                  'default_optimizer_learning_rate': 5e-05,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.7788345),
#                                  'gradients_default_optimizer_global_norm': np.float32(0.21737315),
#                                  'mean_kl_loss': np.float32(0.013955732),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 120704,
#                                  'num_module_steps_trained_lifetime': 120704,
#                                  'num_module_steps_trained_lifetime_throughput': 10015.57464395693,
#                                  'num_trainable_parameters': 389895,
#                                  'policy_loss': np.float32(-0.017261079),
#                                  'total_loss': np.float32(9.9152565),
#                                  'vf_explained_var': np.float32(0.0004454255),
#                                  'vf_loss': np.float32(9.929726),
#                                  'vf_loss_unclipped': np.float32(58658.934),
#                                  'weights_seq_no': 1.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 4000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(43.82916666666667),
#           'ram_util_percent': np.float64(89.6375)},
#  'pid': 2483888,
#  'time_since_restore': 16.543413162231445,
#  'time_this_iter_s': 16.543413162231445,
#  'time_total_s': 16.543413162231445,
#  'timers': {'env_runner_sampling_timer': 3.9963205789681524,
#             'learner_update_timer': 12.525901458924636,
#             'restore_env_runners': 2.1064886823296547e-05,
#             'synch_weights': 0.003982028923928738,
#             'training_iteration': 16.533158812089823,
#             'training_step': 16.53260503790807},
#  'timestamp': 1754287669,
#  'training_iteration': 1,
#  'trial_id': 'default'}
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': <function <lambda> at 0x7feb32864790>,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': None,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Taxi-v3',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 1,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 5e-05,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-08-05',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -733.575},
#                  'env_reset_timer': np.float64(0.000485341006424278),
#                  'env_step_timer': np.float64(0.00013115812045980452),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00032733563724806605),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.2687758156100745e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.380170171638927e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.246326571687605e-05),
#                                                                        'batch_individual_items': np.float64(3.205630625691481e-05),
#                                                                        'flatten_observations': np.float64(7.570001503188639e-05),
#                                                                        'numpy_to_tensor': np.float64(6.139341936299049e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(124.57320249925593),
#                  'env_to_module_sum_episodes_length_out': np.float64(124.57320249925593),
#                  'episode_duration_sec_mean': 0.37803433580265844,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 199.725,
#                  'episode_len_min': 189,
#                  'episode_return_max': -587.0,
#                  'episode_return_mean': -733.575,
#                  'episode_return_min': -884.0,
#                  'module_episode_return_mean': {'default_policy': -733.575},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0008463567686826922),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0004602648586032552),
#                                                                        'listify_data_for_vector_env': np.float64(5.240282756138784e-05),
#                                                                        'normalize_and_clip_actions': np.float64(4.764304204380898e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(2.9741241518129565e-06),
#                                                                        'tensor_to_numpy': np.float64(9.170129643523389e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.8023675230574402e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 4000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 8000.0},
#                  'num_env_steps_sampled': 4000.0,
#                  'num_env_steps_sampled_lifetime': 8000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(510.23260052889685),
#                  'num_episodes': 20.0,
#                  'num_episodes_lifetime': 40.0,
#                  'num_module_steps_sampled': {'default_policy': 4000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 8000.0},
#                  'rlmodule_inference_timer': np.float64(0.0003036756204671105),
#                  'sample': np.float64(3.9019095689151437),
#                  'time_between_sampling': np.float64(12.67372997046914),
#                  'weights_seq_no': 1.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 2,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.2449396033049561,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.10711412473930977,
#                                                                                   'add_observations_from_episodes_to_batch': 0.00031295221531763673,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.008553910774644465,
#                                                                                   'add_states_from_episodes_to_batch': 1.2314558262005448e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.843850339762866e-05,
#                                                                                   'batch_individual_items': 0.0836550058296416,
#                                                                                   'general_advantage_estimation': 0.04439513005083427,
#                                                                                   'numpy_to_tensor': 0.0002541544800624252}}},
#                                   'learner_connector_sum_episodes_length_in': 4000.0,
#                                   'learner_connector_sum_episodes_length_out': 4021.0,
#                                   'num_env_steps_trained': 3791803,
#                                   'num_env_steps_trained_lifetime': 7583606,
#                                   'num_env_steps_trained_lifetime_throughput': 313601.26671003265,
# ...
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-08-56',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -574.72},
#                  'env_reset_timer': np.float64(0.000485341006424278),
#                  'env_step_timer': np.float64(0.00013447277043908434),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.0003391668707922096),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.3263807292582597e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.696677902596683e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.3025828178051431e-05),
#                                                                        'batch_individual_items': np.float64(3.324085645285672e-05),
#                                                                        'flatten_observations': np.float64(7.744630500766454e-05),
#                                                                        'numpy_to_tensor': np.float64(6.22628291816599e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(108.36697026525445),
#                  'env_to_module_sum_episodes_length_out': np.float64(108.36697026525445),
#                  'episode_duration_sec_mean': 0.3746270954958163,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 199.36,
#                  'episode_len_min': 180,
#                  'episode_return_max': -416.0,
#                  'episode_return_mean': -574.72,
#                  'episode_return_min': -758.0,
#                  'module_episode_return_mean': {'default_policy': -574.72},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.000849238739351508),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0004592800823778506),
#                                                                        'listify_data_for_vector_env': np.float64(5.3964904797986534e-05),
#                                                                        'normalize_and_clip_actions': np.float64(4.7897374080069356e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.3432447155720027e-06),
#                                                                        'tensor_to_numpy': np.float64(9.003139494688578e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.8374001896384203e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 4000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 20000.0},
#                  'num_env_steps_sampled': 4000.0,
#                  'num_env_steps_sampled_lifetime': 20000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(495.6712541809198),
#                  'num_episodes': 20.0,
#                  'num_episodes_lifetime': 100.0,
#                  'num_module_steps_sampled': {'default_policy': 4000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 20000.0},
#                  'rlmodule_inference_timer': np.float64(0.00030179972704679446),
#                  'sample': np.float64(3.899279950841977),
#                  'time_between_sampling': np.float64(12.687988226600721),
#                  'weights_seq_no': 4.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 5,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.2459132515643081,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.10691904520503612,
#                                                                                   'add_observations_from_episodes_to_batch': 0.00031426535142887617,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.00861407031010638,
#                                                                                   'add_states_from_episodes_to_batch': 1.2292727449763333e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.8424908155781455e-05,
#                                                                                   'batch_individual_items': 0.08536104090764102,
#                                                                                   'general_advantage_estimation': 0.043799461961334885,
#                                                                                   'numpy_to_tensor': 0.00025430390828087}}},
#                                   'learner_connector_sum_episodes_length_in': 4000.0,
#                                   'learner_connector_sum_episodes_length_out': 4021.0198999999993,
#                                   'num_env_steps_trained': 3792746,
#                                   'num_env_steps_trained_lifetime': 18960901,
#                                   'num_env_steps_trained_lifetime_throughput': 310744.1418464152,
#                                   'num_module_steps_trained': 120704,
#                                   'num_module_steps_trained_lifetime': 603520,
#                                   'num_module_steps_trained_lifetime_throughput': 9892.367217688823,
#                                   'num_module_steps_trained_throughput': 9892.816923236807,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 389895},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 1.0125000476837158,
#                                  'default_optimizer_learning_rate': 5e-05,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.6265576),
#                                  'gradients_default_optimizer_global_norm': np.float32(0.50989556),
#                                  'mean_kl_loss': np.float32(0.022671532),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 120704,
#                                  'num_module_steps_trained_lifetime': 603520,
#                                  'num_module_steps_trained_lifetime_throughput': 9893.200953564612,
#                                  'num_trainable_parameters': 389895,
#                                  'policy_loss': np.float32(-0.11435269),
#                                  'total_loss': np.float32(9.750168),
#                                  'vf_explained_var': np.float32(-0.0009226799),
#                                  'vf_loss': np.float32(9.849216),
#                                  'vf_loss_unclipped': np.float32(28002.352),
#                                  'weights_seq_no': 5.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 20000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(44.58695652173913),
#           'ram_util_percent': np.float64(90.0608695652174)},
#  'pid': 2483888,
#  'time_since_restore': 84.02190375328064,
#  'time_this_iter_s': 16.689526557922363,
#  'time_total_s': 84.02190375328064,
#  'timers': {'env_runner_sampling_timer': 3.993601354128571,
#             'learner_update_timer': 12.541735056326905,
#             'restore_env_runners': 2.1049746651659955e-05,
#             'synch_env_connectors': 0.003256808443051996,
#             'synch_weights': 0.003947735722892195,
#             'training_iteration': 16.546151500392934,
#             'training_step': 16.545595983664246},
#  'timestamp': 1754287736,
#  'training_iteration': 5,
#  'trial_id': 'default'}

# %% [markdown]
# 在脚本结束时，评估训练好的 Algorithm 并释放其所有资源。

# %%
# ... and evaluate it.
pprint(algo.evaluate())

# Release the algo's resources (remote actors, like EnvRunners and Learners).
algo.stop()
# Out:
# {'env_runners': {'agent_episode_return_mean': {'default_agent': -524.9},
#                  'env_reset_timer': 0.0005784661043435335,
#                  'env_step_timer': 0.00012521755513990153,
#                  'env_to_module_connector': {'connector_pipeline_timer': 0.00031241419131039006,
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': 1.2183304170345956e-05,
#                                                                        'add_states_from_episodes_to_batch': 7.226803572083017e-06,
#                                                                        'add_time_dim_to_batch_and_zero_pad': 1.2250860198382362e-05,
#                                                                        'batch_individual_items': 3.216233114627092e-05,
#                                                                        'flatten_observations': 7.306785694877981e-05,
#                                                                        'numpy_to_tensor': 5.656198972738143e-05}}},
#                  'env_to_module_sum_episodes_length_in': 131.73765398537716,
#                  'env_to_module_sum_episodes_length_out': 131.73765398537716,
#                  'episode_duration_sec_mean': 0.33789365249685943,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -389.0,
#                  'episode_return_mean': -524.9,
#                  'episode_return_min': -623.0,
#                  'module_episode_return_mean': {'default_policy': -524.9},
#                  'module_to_env_connector': {'connector_pipeline_timer': 0.0007504566304899544,
#                                              'timers': {'connectors': {'get_actions': 0.0003827215324138144,
#                                                                        'listify_data_for_vector_env': 5.141652317844767e-05,
#                                                                        'normalize_and_clip_actions': 4.608852209540158e-05,
#                                                                        'remove_single_ts_time_rank_from_batch': 2.948659820391043e-06,
#                                                                        'tensor_to_numpy': 8.609528261701862e-05,
#                                                                        'un_batch_to_individual_items': 2.75351632677787e-05}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 2000},
#                  'num_env_steps_sampled': 2000,
#                  'num_env_steps_sampled_lifetime': 2000,
#                  'num_episodes': 10,
#                  'num_episodes_lifetime': 10,
#                  'num_module_steps_sampled': {'default_policy': 2000},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 2000},
#                  'rlmodule_inference_timer': 0.00025601969222984383,
#                  'sample': 3.433640982955694,
#                  'weights_seq_no': 5.0}}

# %% [markdown]
# # RLlib 的基本构建流程
# 可以通过调用 config 的 environment() 方法来设置要使用的强化学习环境。env_runners()方法来设置希望利用多少 EnvRunner Actor。training()来设置与训练相关的或任何算法特定的参数。 build_algo() 方法来构建实际的 Algorithm 实例。

# %%
from ray.rllib.algorithms.ppo import PPOConfig

# Create a config instance for the PPO algorithm.
config = (
    PPOConfig()
    .environment("Pendulum-v1")
)

config.env_runners(num_env_runners=2)

config.training(
    lr=0.0002,
    train_batch_size_per_learner=2000,
    num_epochs=10,
)

# Build the Algorithm (PPO).
ppo = config.build_algo()
# Out:
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2025-08-04 14:42:14,831 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'ec530fdf6ae7223a6c0541b901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# [2025-08-04 14:42:14,874 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'eaa7967874e40e4bd40a12ce01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# 2025-08-04 14:42:18,656	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %% [markdown]
# 调用 train() 方法对其进行多次迭代训练。save_to_path() 方法创建一个检查点，该方法返回保存检查点的目录。

# %%
from pprint import pprint
import os

for _ in range(4):
    pprint(ppo.train())

abs_path = os.path.abspath("./checkpoints")
checkpoint_path = ppo.save(checkpoint_dir=f"file://{abs_path}")
# checkpoint_path = ppo.save_to_path(os.getcwd())
print("checkpoint path: ", checkpoint_path)
# OR:
# ppo.save_to_path([a checkpoint location of your choice])
# Out:
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': None,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': 2000,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Pendulum-v1',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 0,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 0.0002,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 10,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_15-09-02',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1304.4835280067239},
#                  'env_reset_timer': np.float64(0.0008671475225128233),
#                  'env_step_timer': np.float64(0.00010835908068137481),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.0002201600636607381),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.3958356851743087e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.314483475012568e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.215472731598079e-05),
#                                                                        'batch_individual_items': np.float64(2.9389454286800377e-05),
#                                                                        'numpy_to_tensor': np.float64(5.683260203284632e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765420742725),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765420742725),
#                  'episode_duration_sec_mean': 0.3386907864850946,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -772.7075640448641,
#                  'episode_return_mean': -1304.4835280067239,
#                  'episode_return_min': -1830.9123384919776,
#                  'module_episode_return_mean': {'default_policy': -1304.4835280067239},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0007787676494568817),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0003474185608283338),
#                                                                        'listify_data_for_vector_env': np.float64(4.780929822559566e-05),
#                                                                        'normalize_and_clip_actions': np.float64(9.080381193846807e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.1742839795245606e-06),
#                                                                        'tensor_to_numpy': np.float64(9.079749253373376e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.8318566333581965e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 18000.0},
#                  'num_env_steps_sampled': 2000.0,
#                  'num_env_steps_sampled_lifetime': 18000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(39.477654100109895),
#                  'num_episodes': 10.0,
#                  'num_episodes_lifetime': 90.0,
#                  'num_module_steps_sampled': {'default_policy': 2000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 18000.0},
#                  'rlmodule_inference_timer': np.float64(0.00031050424334692477),
#                  'sample': np.float64(1.7305521932192178),
#                  'time_between_sampling': np.float64(16.579193571936273),
#                  'weights_seq_no': 8.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 9,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.13168863331053005,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.05409033003126348,
#                                                                                   'add_observations_from_episodes_to_batch': 0.0001580171812430984,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.0033850530946683693,
#                                                                                   'add_states_from_episodes_to_batch': 1.192240928943637e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.804755523202691e-05,
#                                                                                   'batch_individual_items': 0.03949902449870713,
#                                                                                   'general_advantage_estimation': 0.033628336279135335,
#                                                                                   'numpy_to_tensor': 0.0002863492013964228}}},
#                                   'learner_connector_sum_episodes_length_in': 2000.0,
#                                   'learner_connector_sum_episodes_length_out': 2010.0,
#                                   'num_env_steps_trained': 317580,
#                                   'num_env_steps_trained_lifetime': 2858220,
#                                   'num_env_steps_trained_lifetime_throughput': 181185.28845622396,
#                                   'num_module_steps_trained': 20224,
#                                   'num_module_steps_trained_lifetime': 182016,
#                                   'num_module_steps_trained_lifetime_throughput': 11538.12219616337,
#                                   'num_module_steps_trained_throughput': 11538.100235185864,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 134403},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.30000001192092896,
#                                  'default_optimizer_learning_rate': 0.0002,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.4455509),
#                                  'gradients_default_optimizer_global_norm': np.float32(1.1639638),
#                                  'mean_kl_loss': np.float32(0.010679134),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 20224,
#                                  'num_module_steps_trained_lifetime': 182016,
#                                  'num_module_steps_trained_lifetime_throughput': 11538.146845265266,
#                                  'num_trainable_parameters': 134403,
#                                  'policy_loss': np.float32(0.025589269),
#                                  'total_loss': np.float32(9.985974),
#                                  'vf_explained_var': np.float32(0.001721859),
#                                  'vf_loss': np.float32(9.957181),
#                                  'vf_loss_unclipped': np.float32(127641.06),
#                                  'weights_seq_no': 9.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 18000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(7.957245080500895),
#           'ram_util_percent': np.float64(92.85635062611806)},
#  'pid': 2483888,
#  'time_since_restore': 32.752925872802734,
#  'time_this_iter_s': 3.5777370929718018,
#  'time_total_s': 32.752925872802734,
#  'timers': {'env_runner_sampling_timer': 1.825783994117825,
#             'learner_update_timer': 1.9185119910983672,
#             'restore_env_runners': 2.1653806131992337e-05,
#             'synch_env_connectors': 0.0029521425835188557,
#             'synch_weights': 0.002921198508648937,
#             'training_iteration': 3.748318025748883,
#             'training_step': 3.7478344988484174},
#  'timestamp': 1754291342,
#  'training_iteration': 9,
#  'trial_id': 'default'}
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': None,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': 2000,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Pendulum-v1',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 0,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 0.0002,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 10,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_15-09-05',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1299.7204758950343},
#                  'env_reset_timer': np.float64(0.0008671475225128233),
#                  'env_step_timer': np.float64(0.00011187796592764012),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00022718592000002747),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.4538852273197046e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.438179033869653e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.2587987929119598e-05),
#                                                                        'batch_individual_items': np.float64(3.056870770594083e-05),
#                                                                        'numpy_to_tensor': np.float64(5.863217823552419e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765420742725),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765420742725),
#                  'episode_duration_sec_mean': 0.3368876504059881,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -772.7075640448641,
#                  'episode_return_mean': -1299.7204758950343,
#                  'episode_return_min': -1830.9123384919776,
#                  'module_episode_return_mean': {'default_policy': -1299.7204758950343},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0007507068598680905),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.00033024134148871664),
#                                                                        'listify_data_for_vector_env': np.float64(4.751977528569255e-05),
#                                                                        'normalize_and_clip_actions': np.float64(9.029182131707039e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.1428097123626735e-06),
#                                                                        'tensor_to_numpy': np.float64(8.644447957109592e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.7834809046506267e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 20000.0},
#                  'num_env_steps_sampled': 2000.0,
#                  'num_env_steps_sampled_lifetime': 20000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(44.072676244831584),
#                  'num_episodes': 10.0,
#                  'num_episodes_lifetime': 100.0,
#                  'num_module_steps_sampled': {'default_policy': 2000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 20000.0},
#                  'rlmodule_inference_timer': np.float64(0.00029403225890284324),
#                  'sample': np.float64(1.7297689378921963),
#                  'time_between_sampling': np.float64(16.43231751007657),
#                  'weights_seq_no': 9.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 10,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.13138559222696958,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.0540559920712798,
#                                                                                   'add_observations_from_episodes_to_batch': 0.00015799322966224518,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.00338144136323966,
#                                                                                   'add_states_from_episodes_to_batch': 1.1896894873999816e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.8010899527037096e-05,
#                                                                                   'batch_individual_items': 0.03947282122364068,
#                                                                                   'general_advantage_estimation': 0.03339129943689304,
#                                                                                   'numpy_to_tensor': 0.00028596825913549865}}},
#                                   'learner_connector_sum_episodes_length_in': 2000.0,
#                                   'learner_connector_sum_episodes_length_out': 2010.0,
#                                   'num_env_steps_trained': 317580,
#                                   'num_env_steps_trained_lifetime': 3175800,
#                                   'num_env_steps_trained_lifetime_throughput': 181540.068087691,
#                                   'num_module_steps_trained': 20224,
#                                   'num_module_steps_trained_lifetime': 202240,
#                                   'num_module_steps_trained_lifetime_throughput': 11560.696264895152,
#                                   'num_module_steps_trained_throughput': 11560.644322169981,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 134403},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.15000000596046448,
#                                  'default_optimizer_learning_rate': 0.0002,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.2640603),
#                                  'gradients_default_optimizer_global_norm': np.float32(0.7695258),
#                                  'mean_kl_loss': np.float32(0.0043692747),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 20224,
#                                  'num_module_steps_trained_lifetime': 202240,
#                                  'num_module_steps_trained_lifetime_throughput': 11560.670856591894,
#                                  'num_trainable_parameters': 134403,
#                                  'policy_loss': np.float32(-0.119699776),
#                                  'total_loss': np.float32(9.832036),
#                                  'vf_explained_var': np.float32(0.006079972),
#                                  'vf_loss': np.float32(9.950426),
#                                  'vf_loss_unclipped': np.float32(173741.89),
#                                  'weights_seq_no': 10.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 20000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(36.660000000000004),
#           'ram_util_percent': np.float64(92.4)},
#  'pid': 2483888,
#  'time_since_restore': 36.21864175796509,
#  'time_this_iter_s': 3.4657158851623535,
#  'time_total_s': 36.21864175796509,
#  'timers': {'env_runner_sampling_timer': 1.8245170549159757,
#             'learner_update_timer': 1.916873245987533,
#             'restore_env_runners': 2.1639787656982203e-05,
#             'synch_env_connectors': 0.0029525596371034646,
#             'synch_weights': 0.002919814743607642,
#             'training_iteration': 3.745411327800888,
#             'training_step': 3.744927304280167},
#  'timestamp': 1754291345,
#  'training_iteration': 10,
#  'trial_id': 'default'}
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': None,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': 2000,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
# ...
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_15-09-12',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1296.952015702633},
#                  'env_reset_timer': np.float64(0.0008671475225128233),
#                  'env_step_timer': np.float64(0.0001105370703281079),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00022310911659278532),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.4206817503040486e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.266937440392181e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.2351210748205671e-05),
#                                                                        'batch_individual_items': np.float64(3.0091052558063496e-05),
#                                                                        'numpy_to_tensor': np.float64(5.780363196173632e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765420742725),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765420742725),
#                  'episode_duration_sec_mean': 0.33727928590262307,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -752.1804346919448,
#                  'episode_return_mean': -1296.952015702633,
#                  'episode_return_min': -1831.7946534686791,
#                  'module_episode_return_mean': {'default_policy': -1296.952015702633},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0007509493864887617),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0003301137791249691),
#                                                                        'listify_data_for_vector_env': np.float64(4.7675567710360743e-05),
#                                                                        'normalize_and_clip_actions': np.float64(8.975630930969382e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.0491414498180293e-06),
#                                                                        'tensor_to_numpy': np.float64(8.70953785332958e-05),
#                                                                        'un_batch_to_individual_items': np.float64(2.7711130161112933e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 24000.0},
#                  'num_env_steps_sampled': 2000.0,
#                  'num_env_steps_sampled_lifetime': 24000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(54.667581489754355),
#                  'num_episodes': 10.0,
#                  'num_episodes_lifetime': 120.0,
#                  'num_module_steps_sampled': {'default_policy': 2000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 24000.0},
#                  'rlmodule_inference_timer': np.float64(0.0002952638283675377),
#                  'sample': np.float64(1.728913863188367),
#                  'time_between_sampling': np.float64(16.14260304717937),
#                  'weights_seq_no': 11.0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 12,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.130939172566879,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.05410435564093345,
#                                                                                   'add_observations_from_episodes_to_batch': 0.0001582215527599733,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.003381486941127507,
#                                                                                   'add_states_from_episodes_to_batch': 1.1893614962944863e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 3.8055062331259e-05,
#                                                                                   'batch_individual_items': 0.039460085145788554,
#                                                                                   'general_advantage_estimation': 0.03291171812524695,
#                                                                                   'numpy_to_tensor': 0.0002857986008514342}}},
#                                   'learner_connector_sum_episodes_length_in': 2000.0,
#                                   'learner_connector_sum_episodes_length_out': 2010.0,
#                                   'num_env_steps_trained': 317580,
#                                   'num_env_steps_trained_lifetime': 3810960,
#                                   'num_env_steps_trained_lifetime_throughput': 182507.0386180838,
#                                   'num_module_steps_trained': 20224,
#                                   'num_module_steps_trained_lifetime': 242688,
#                                   'num_module_steps_trained_lifetime_throughput': 11622.364221622072,
#                                   'num_module_steps_trained_throughput': 11622.369990207859,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 134403},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.22500000894069672,
#                                  'default_optimizer_learning_rate': 0.0002,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.3557665),
#                                  'gradients_default_optimizer_global_norm': np.float32(0.89085865),
#                                  'mean_kl_loss': np.float32(0.023838699),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 20224,
#                                  'num_module_steps_trained_lifetime': 242688,
#                                  'num_module_steps_trained_lifetime_throughput': 11622.4256021982,
#                                  'num_trainable_parameters': 134403,
#                                  'policy_loss': np.float32(0.01145545),
#                                  'total_loss': np.float32(9.88635),
#                                  'vf_explained_var': np.float32(0.005641997),
#                                  'vf_loss': np.float32(9.871318),
#                                  'vf_loss_unclipped': np.float32(192671.88),
#                                  'weights_seq_no': 12.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 24000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(35.239999999999995),
#           'ram_util_percent': np.float64(92.36)},
#  'pid': 2483888,
#  'time_since_restore': 43.32107758522034,
#  'time_this_iter_s': 3.5269014835357666,
#  'time_total_s': 43.32107758522034,
#  'timers': {'env_runner_sampling_timer': 1.8228221550292383,
#             'learner_update_timer': 1.9145164967527148,
#             'restore_env_runners': 2.399866159343358e-05,
#             'synch_env_connectors': 0.0029499206761224453,
#             'synch_weights': 0.0029199344041811754,
#             'training_iteration': 3.7413636741312546,
#             'training_step': 3.7408763846818873},
#  'timestamp': 1754291352,
#  'training_iteration': 12,
#  'trial_id': 'default'}
# checkpoint path:  TrainingResult(checkpoint=Checkpoint(filesystem=local, path=file:///home/robotarm/data/Ray_Tutorial/checkpoints), metrics={'timers': {'training_iteration': 3.7413636741312546, 'restore_env_runners': 2.399866159343358e-05, 'training_step': 3.7408763846818873, 'env_runner_sampling_timer': 1.8228221550292383, 'learner_update_timer': 1.9145164967527148, 'synch_weights': 0.0029199344041811754, 'synch_env_connectors': 0.0029499206761224453}, 'env_runners': {'module_to_env_connector': {'timers': {'connectors': {'listify_data_for_vector_env': np.float64(4.7675567710360743e-05), 'un_batch_to_individual_items': np.float64(2.7711130161112933e-05), 'remove_single_ts_time_rank_from_batch': np.float64(3.0491414498180293e-06), 'normalize_and_clip_actions': np.float64(8.975630930969382e-05), 'get_actions': np.float64(0.0003301137791249691), 'tensor_to_numpy': np.float64(8.70953785332958e-05)}}, 'connector_pipeline_timer': np.float64(0.0007509493864887617)}, 'env_to_module_connector': {'timers': {'connectors': {'numpy_to_tensor': np.float64(5.780363196173632e-05), 'add_observations_from_episodes_to_batch': np.float64(1.4206817503040486e-05), 'add_time_dim_to_batch_and_zero_pad': np.float64(1.2351210748205671e-05), 'batch_individual_items': np.float64(3.0091052558063496e-05), 'add_states_from_episodes_to_batch': np.float64(7.266937440392181e-06)}}, 'connector_pipeline_timer': np.float64(0.00022310911659278532)}, 'num_env_steps_sampled': 2000.0, 'num_module_steps_sampled': {'default_policy': 2000.0}, 'episode_len_max': 200, 'num_episodes_lifetime': 120.0, 'episode_return_max': -752.1804346919448, 'agent_episode_return_mean': {'default_agent': -1296.952015702633}, 'rlmodule_inference_timer': np.float64(0.0002952638283675377), 'num_episodes': 10.0, 'num_module_steps_sampled_lifetime': {'default_policy': 24000.0}, 'env_reset_timer': np.float64(0.0008671475225128233), 'module_episode_return_mean': {'default_policy': -1296.952015702633}, 'env_to_module_sum_episodes_length_in': np.float64(131.73765420742725), 'episode_len_min': 200, 'env_step_timer': np.float64(0.0001105370703281079), 'episode_return_mean': -1296.952015702633, 'episode_len_mean': 200.0, 'episode_return_min': -1831.7946534686791, 'episode_duration_sec_mean': 0.33727928590262307, 'sample': np.float64(1.728913863188367), 'num_env_steps_sampled_lifetime': 24000.0, 'weights_seq_no': 11.0, 'num_agent_steps_sampled_lifetime': {'default_agent': 24000.0}, 'env_to_module_sum_episodes_length_out': np.float64(131.73765420742725), 'num_agent_steps_sampled': {'default_agent': 2000.0}, 'time_between_sampling': np.float64(16.14260304717937), 'num_env_steps_sampled_lifetime_throughput': np.float64(54.667581489754355)}, 'learners': {'default_policy': {'num_module_steps_trained': 20224, 'num_module_steps_trained_lifetime': 242688, 'default_optimizer_learning_rate': 0.0002, 'total_loss': np.float32(9.88635), 'policy_loss': np.float32(0.01145545), 'vf_explained_var': np.float32(0.005641997), 'entropy': np.float32(1.3557665), 'vf_loss': np.float32(9.871318), 'vf_loss_unclipped': np.float32(192671.88), 'curr_kl_coeff': 0.22500000894069672, 'gradients_default_optimizer_global_norm': np.float32(0.89085865), 'mean_kl_loss': np.float32(0.023838699), 'module_train_batch_size_mean': 128.0, 'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0), 'curr_entropy_coeff': 0.0, 'weights_seq_no': 12.0, 'num_trainable_parameters': 134403, 'num_module_steps_trained_lifetime_throughput': 11622.4256021982}, '__all_modules__': {'learner_connector_sum_episodes_length_out': 2010.0, 'learner_connector': {'connector_pipeline_timer': 0.130939172566879, 'timers': {'connectors': {'add_observations_from_episodes_to_batch': 0.0001582215527599733, 'add_time_dim_to_batch_and_zero_pad': 3.8055062331259e-05, 'batch_individual_items': 0.039460085145788554, 'add_states_from_episodes_to_batch': 1.1893614962944863e-05, 'add_columns_from_episodes_to_train_batch': 0.05410435564093345, 'general_advantage_estimation': 0.0329 ...

# %%
config.evaluation(
    # Run one evaluation round every iteration.
    evaluation_interval=1,

    # Create 2 eval EnvRunners in the extra EnvRunnerGroup.
    evaluation_num_env_runners=2,

    # Run evaluation for exactly 10 episodes. Note that because you have
    # 2 EnvRunners, each one runs through 5 episodes.
    evaluation_duration_unit="episodes",
    evaluation_duration=10,
)

# Rebuild the PPO, but with the extra evaluation EnvRunnerGroup
ppo_with_evaluation = config.build_algo()

for _ in range(3):
    pprint(ppo_with_evaluation.train())
# Out:
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/robotarm/anaconda3/envs/ray_env/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2025-08-04 14:45:36,718 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'ee84b34ab9fe8ad6ba59e43c01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# [2025-08-04 14:45:36,762 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: 'a1f91987fab2d97bd017118501000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# [2025-08-04 14:45:40,956 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: '30c3ce877dd95f9ca80d835901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# [2025-08-04 14:45:40,995 E 2483888 2483888] core_worker.cc:2740: Actor with class name: 'SingleAgentEnvRunner' and ID: '5a97927bb80b2d61be24298e01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': None,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': 2000,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Pendulum-v1',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': 1,
#             'evaluation_num_env_runners': 2,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 0.0002,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 10,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-45-51',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1140.599092381352},
#                  'env_reset_timer': np.float64(0.0007428214885294437),
#                  'env_step_timer': np.float64(0.00011935442692576569),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00023405390142497114),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.569860854732136e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.682323395711945e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.198585127999602e-05),
#                                                                        'batch_individual_items': np.float64(3.107093201387687e-05),
#                                                                        'numpy_to_tensor': np.float64(6.044663312570769e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.7322456618175),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.7322456618175),
#                  'episode_duration_sec_mean': 0.3638926294865087,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -996.4394903562311,
#                  'episode_return_mean': -1140.599092381352,
#                  'episode_return_min': -1366.2231501934227,
#                  'module_episode_return_mean': {'default_policy': -1140.599092381352},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0008030257811381507),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.00035395897819145376),
#                                                                        'listify_data_for_vector_env': np.float64(5.148185957265464e-05),
#                                                                        'normalize_and_clip_actions': np.float64(9.718155346924545e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.3674037622712217e-06),
#                                                                        'tensor_to_numpy': np.float64(9.038815892714247e-05),
#                                                                        'un_batch_to_individual_items': np.float64(3.1744895657215454e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 2000.0},
#                  'num_env_steps_sampled': 2000.0,
#                  'num_env_steps_sampled_lifetime': 2000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(539.4445183938877),
#                  'num_episodes': 10.0,
#                  'num_episodes_lifetime': 10.0,
#                  'num_module_steps_sampled': {'default_policy': 2000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 2000.0},
#                  'rlmodule_inference_timer': np.float64(0.0003213258297547523),
#                  'sample': np.float64(1.8496505920193158),
#                  'weights_seq_no': 0.0},
#  'evaluation': {'actor_manager_num_outstanding_async_reqs': 1,
#                 'env_runners': {'agent_episode_return_mean': {'default_agent': -1169.0781175041982},
#                                 'env_reset_timer': np.float64(0.0007530724979005753),
#                                 'env_step_timer': np.float64(0.00011881388528787152),
#                                 'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00023174543731518837),
#                                                             'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.5798587729349618e-05),
#                                                                                       'add_states_from_episodes_to_batch': np.float64(7.669112906274522e-06),
#                                                                                       'add_time_dim_to_batch_and_zero_pad': np.float64(1.2376197583095343e-05),
#                                                                                       'batch_individual_items': np.float64(3.089502872262923e-05),
#                                                                                       'numpy_to_tensor': np.float64(6.003280098239045e-05)}}},
#                                 'env_to_module_sum_episodes_length_in': np.float64(131.7322456618175),
#                                 'env_to_module_sum_episodes_length_out': np.float64(131.7322456618175),
#                                 'episode_duration_sec_mean': 0.3400389423011802,
#                                 'episode_len_max': 200,
#                                 'episode_len_mean': 200.0,
#                                 'episode_len_min': 200,
#                                 'episode_return_max': -1057.6370486097605,
#                                 'episode_return_mean': -1169.0781175041982,
#                                 'episode_return_min': -1342.006610217249,
#                                 'module_episode_return_mean': {'default_policy': -1169.0781175041982},
#                                 'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.000769042567650985),
#                                                             'timers': {'connectors': {'get_actions': np.float64(0.00033802282447994937),
#                                                                                       'listify_data_for_vector_env': np.float64(4.9221097822315984e-05),
#                                                                                       'normalize_and_clip_actions': np.float64(9.358119054716905e-05),
#                                                                                       'remove_single_ts_time_rank_from_batch': np.float64(3.2526775762623475e-06),
#                                                                                       'tensor_to_numpy': np.float64(8.655908011757949e-05),
#                                                                                       'un_batch_to_individual_items': np.float64(2.985300280221954e-05)}}},
#                                 'num_agent_steps_sampled': {'default_agent': 2000.0},
#                                 'num_agent_steps_sampled_lifetime': {'default_agent': 2000.0},
#                                 'num_env_steps_sampled': 2000.0,
#                                 'num_env_steps_sampled_lifetime': 2000.0,
#                                 'num_episodes': 10.0,
#                                 'num_episodes_lifetime': 10.0,
#                                 'num_module_steps_sampled': {'default_policy': 2000.0},
#                                 'num_module_steps_sampled_lifetime': {'default_policy': 2000.0},
#                                 'rlmodule_inference_timer': np.float64(0.0003055257373677666),
#                                 'sample': np.float64(1.7268439994659275),
#                                 'weights_seq_no': 1.0},
#                 'num_healthy_workers': 2,
#                 'num_remote_worker_restarts': 0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 1,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.14356235298328102,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.05690284597221762,
#                                                                                   'add_observations_from_episodes_to_batch': 0.0002645980566740036,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.006567261065356433,
#                                                                                   'add_states_from_episodes_to_batch': 1.2126052752137184e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 5.366094410419464e-05,
#                                                                                   'batch_individual_items': 0.04242825601249933,
#                                                                                   'general_advantage_estimation': 0.036332804011181,
#                                                                                   'numpy_to_tensor': 0.0003580610500648618}}},
#                                   'learner_connector_sum_episodes_length_in': 2000,
#                                   'learner_connector_sum_episodes_length_out': 2010,
#                                   'num_env_steps_trained': 317580,
#                                   'num_env_steps_trained_lifetime': 317580,
#                                   'num_env_steps_trained_lifetime_throughput': 180664.5573071467,
#                                   'num_module_steps_trained': 20224,
#                                   'num_module_steps_trained_lifetime': 20224,
#                                   'num_module_steps_trained_lifetime_throughput': 11503.559877058346,
#                                   'num_module_steps_trained_throughput': 11502.937861406765,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 134403},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.30000001192092896,
#                                  'default_optimizer_learning_rate': 0.0002,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.5016942),
#                                  'gradients_default_optimizer_global_norm': np.float32(1.8125764),
#                                  'mean_kl_loss': np.float32(0.030051349),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 20224,
#                                  'num_module_steps_trained_lifetime': 20224,
#                                  'num_module_steps_trained_lifetime_throughput': 11502.357003164443,
#                                  'num_trainable_parameters': 134403,
#                                  'policy_loss': np.float32(0.032949574),
#                                  'total_loss': np.float32(9.914086),
#                                  'vf_explained_var': np.float32(-0.0002220869),
#                                  'vf_loss': np.float32(9.875127),
#                                  'vf_loss_unclipped': np.float32(124253.09),
#                                  'weights_seq_no': 1.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 2000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(32.6),
#           'gpu_util_percent0': np.float64(0.16749999999999998),
#           'gpu_util_percent1': np.float64(0.0),
#           'ram_util_percent': np.float64(93.9625),
#           'vram_util_percent0': np.float64(0.1953125),
#           'vram_util_percent1': np.float64(0.0005699397492265104)},
#  'pid': 2483888,
#  'time_since_restore': 5.646574258804321,
#  'time_this_iter_s': 5.646574258804321,
#  'time_total_s': 5.646574258804321,
#  'timers': {'env_runner_sampling_timer': 1.9063749100314453,
#             'learner_update_timer': 1.9457671840209514,
#             'restore_env_runners': 2.267700619995594e-05,
#             'synch_weights': 0.003132050042040646,
#             'training_iteration': 3.8563622949877754,
#             'training_step': 3.855978003004566},
#  'timestamp': 1754289951,
#  'training_iteration': 1,
#  'trial_id': 'default'}
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': None,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': 2000,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Pendulum-v1',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': 1,
#             'evaluation_num_env_runners': 2,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'SYNC',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': True,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 0.0002,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 10,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-45-57',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1139.219045645229},
#                  'env_reset_timer': np.float64(0.0007428214885294437),
#                  'env_step_timer': np.float64(0.0001509336386030002),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00035369421163707613),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(6.033178375095277e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(1.0493358635824047e-05),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.6162036644375494e-05),
#                                                                        'batch_individual_items': np.float64(4.0702369245517616e-05),
#                                                                        'numpy_to_tensor': np.float64(7.855898335959677e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765398537716),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765398537716),
#                  'episode_duration_sec_mean': 0.38397806549910457,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -996.4394903562311,
#                  'episode_return_mean': -1139.219045645229,
#                  'episode_return_min': -1366.2231501934227,
# ...
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x7fec33eadea0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2025-08-04_14-46-03',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': -1123.3116867697063},
#                  'env_reset_timer': np.float64(0.0007428214885294437),
#                  'env_step_timer': np.float64(0.00011745841419467526),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00023656278962491944),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.5208048511749982e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(7.699151858558933e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.2416527147096236e-05),
#                                                                        'batch_individual_items': np.float64(3.105962623081245e-05),
#                                                                        'numpy_to_tensor': np.float64(6.00273367176446e-05)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765420741816),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765420741816),
#                  'episode_duration_sec_mean': 0.36809821823456634,
#                  'episode_len_max': 200,
#                  'episode_len_mean': 200.0,
#                  'episode_len_min': 200,
#                  'episode_return_max': -891.2929852784258,
#                  'episode_return_mean': -1123.3116867697063,
#                  'episode_return_min': -1366.2231501934227,
#                  'module_episode_return_mean': {'default_policy': -1123.3116867697063},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0007659499214536204),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0003206401603386826),
#                                                                        'listify_data_for_vector_env': np.float64(5.20195298255202e-05),
#                                                                        'normalize_and_clip_actions': np.float64(9.579950874600153e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(3.434406051980231e-06),
#                                                                        'tensor_to_numpy': np.float64(9.218850593900611e-05),
#                                                                        'un_batch_to_individual_items': np.float64(3.0182962214944563e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': 2000.0},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 6000.0},
#                  'num_env_steps_sampled': 2000.0,
#                  'num_env_steps_sampled_lifetime': 6000.0,
#                  'num_env_steps_sampled_lifetime_throughput': np.float64(534.2978094853615),
#                  'num_episodes': 10.0,
#                  'num_episodes_lifetime': 30.0,
#                  'num_module_steps_sampled': {'default_policy': 2000.0},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 6000.0},
#                  'rlmodule_inference_timer': np.float64(0.00030347792186570977),
#                  'sample': np.float64(1.8502502247026773),
#                  'time_between_sampling': np.float64(3.8491757735901047),
#                  'weights_seq_no': 2.0},
#  'evaluation': {'actor_manager_num_outstanding_async_reqs': 1,
#                 'env_runners': {'agent_episode_return_mean': {'default_agent': -1154.3866295759478},
#                                 'env_reset_timer': np.float64(0.0007375590085635864),
#                                 'env_step_timer': np.float64(0.00011630044688794585),
#                                 'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.00023698858159172448),
#                                                             'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.5216445641048878e-05),
#                                                                                       'add_states_from_episodes_to_batch': np.float64(8.0140669905858e-06),
#                                                                                       'add_time_dim_to_batch_and_zero_pad': np.float64(1.2805293925468061e-05),
#                                                                                       'batch_individual_items': np.float64(3.1314980651355874e-05),
#                                                                                       'numpy_to_tensor': np.float64(6.0232817866265315e-05)}}},
#                                 'env_to_module_sum_episodes_length_in': np.float64(131.7376542074227),
#                                 'env_to_module_sum_episodes_length_out': np.float64(131.7376542074227),
#                                 'episode_duration_sec_mean': 0.33710150981076165,
#                                 'episode_len_max': 200,
#                                 'episode_len_mean': 200.0,
#                                 'episode_len_min': 200,
#                                 'episode_return_max': -883.4536483035556,
#                                 'episode_return_mean': -1154.3866295759478,
#                                 'episode_return_min': -1649.6998396855536,
#                                 'module_episode_return_mean': {'default_policy': -1154.3866295759478},
#                                 'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0007731492154110146),
#                                                             'timers': {'connectors': {'get_actions': np.float64(0.0003356959283545172),
#                                                                                       'listify_data_for_vector_env': np.float64(4.9738470791565404e-05),
#                                                                                       'normalize_and_clip_actions': np.float64(9.39804234470202e-05),
#                                                                                       'remove_single_ts_time_rank_from_batch': np.float64(3.2988389153106975e-06),
#                                                                                       'tensor_to_numpy': np.float64(8.987479814087152e-05),
#                                                                                       'un_batch_to_individual_items': np.float64(2.9738867899803958e-05)}}},
#                                 'num_agent_steps_sampled': {'default_agent': 2000.0},
#                                 'num_agent_steps_sampled_lifetime': {'default_agent': 6000.0},
#                                 'num_env_steps_sampled': 2000.0,
#                                 'num_env_steps_sampled_lifetime': 800.0,
#                                 'num_episodes': 10.0,
#                                 'num_episodes_lifetime': 30.0,
#                                 'num_module_steps_sampled': {'default_policy': 2000.0},
#                                 'num_module_steps_sampled_lifetime': {'default_policy': 6000.0},
#                                 'rlmodule_inference_timer': np.float64(0.00030773072900183685),
#                                 'sample': np.float64(1.7197653992205835),
#                                 'time_between_sampling': np.float64(2.2720879378821475),
#                                 'weights_seq_no': 3.0},
#                 'num_healthy_workers': 2,
#                 'num_remote_worker_restarts': 0},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'robotarm-Precision-7920-Tower',
#  'iterations_since_restore': 3,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': 0.14369523573238402,
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': 0.05714611173967133,
#                                                                                   'add_observations_from_episodes_to_batch': 0.00026442666646325964,
#                                                                                   'add_one_ts_to_episodes_and_truncate': 0.00654723248911323,
#                                                                                   'add_states_from_episodes_to_batch': 1.2189497554209083e-05,
#                                                                                   'add_time_dim_to_batch_and_zero_pad': 5.342263048514724e-05,
#                                                                                   'batch_individual_items': 0.042876167333277405,
#                                                                                   'general_advantage_estimation': 0.0357984177497332,
#                                                                                   'numpy_to_tensor': 0.0003569482894032262}}},
#                                   'learner_connector_sum_episodes_length_in': 2000.0,
#                                   'learner_connector_sum_episodes_length_out': 2010.0,
#                                   'num_env_steps_trained': 317580,
#                                   'num_env_steps_trained_lifetime': 952740,
#                                   'num_env_steps_trained_lifetime_throughput': 180783.09710031364,
#                                   'num_module_steps_trained': 20224,
#                                   'num_module_steps_trained_lifetime': 60672,
#                                   'num_module_steps_trained_lifetime_throughput': 11511.278614618835,
#                                   'num_module_steps_trained_throughput': 11510.71080997817,
#                                   'num_non_trainable_parameters': 0,
#                                   'num_trainable_parameters': 134403},
#               'default_policy': {'curr_entropy_coeff': 0.0,
#                                  'curr_kl_coeff': 0.30000001192092896,
#                                  'default_optimizer_learning_rate': 0.0002,
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0),
#                                  'entropy': np.float32(1.3875077),
#                                  'gradients_default_optimizer_global_norm': np.float32(2.3048549),
#                                  'mean_kl_loss': np.float32(0.015678402),
#                                  'module_train_batch_size_mean': 128.0,
#                                  'num_module_steps_trained': 20224,
#                                  'num_module_steps_trained_lifetime': 60672,
#                                  'num_module_steps_trained_lifetime_throughput': 11510.181918198976,
#                                  'num_trainable_parameters': 134403,
#                                  'policy_loss': np.float32(-0.115843296),
#                                  'total_loss': np.float32(9.678733),
#                                  'vf_explained_var': np.float32(-0.007081628),
#                                  'vf_loss': np.float32(9.789873),
#                                  'vf_loss_unclipped': np.float32(104285.53),
#                                  'weights_seq_no': 3.0}},
#  'node_ip': '10.110.34.88',
#  'num_env_steps_sampled_lifetime': 6000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(28.916666666666668),
#           'gpu_util_percent0': np.float64(0.11166666666666665),
#           'gpu_util_percent1': np.float64(0.0),
#           'ram_util_percent': np.float64(90.7),
#           'vram_util_percent0': np.float64(0.218994140625),
#           'vram_util_percent1': np.float64(0.0005699397492265104)},
#  'pid': 2483888,
#  'time_since_restore': 17.067107677459717,
#  'time_this_iter_s': 5.21979284286499,
#  'time_total_s': 17.067107677459717,
#  'timers': {'env_runner_sampling_timer': 1.9068884597590425,
#             'evaluation_iteration': 1.7817583419184666,
#             'learner_update_timer': 1.9466648585035815,
#             'restore_env_runners': 2.2720657649915665e-05,
#             'restore_eval_env_runners': 2.0282563054934142e-05,
#             'synch_env_connectors': 0.0032855385961011053,
#             'synch_eval_env_connectors': 0.0007782564009539782,
#             'synch_weights': 0.003130366569501348,
#             'training_iteration': 3.8577765029151574,
#             'training_step': 3.8573862868282824},
#  'timestamp': 1754289963,
#  'training_iteration': 3,
#  'trial_id': 'default'}

# %% [markdown]
# # RLlib 与 Ray Tune 结合
# PPO 进行超参数扫描，创建三个 Trials。

# %%
from ray import train, tune
from ray.rllib.algorithms.ppo import PPOConfig
import os
abs_path = os.path.abspath("./checkpoints")

config = (
    PPOConfig()
    .environment("Pendulum-v1")
    # Specify a simple tune hyperparameter sweep.
    .training(
        lr=tune.grid_search([0.001, 0.0005, 0.0001]),
    )
    .framework("torch")
)

# Create a Tuner instance to manage the trials.
tuner = tune.Tuner(
    config.algo_class,
    param_space=config,
    # Specify a stopping criterion. Note that the criterion has to match one of the
    # pretty printed result metrics from the results returned previously by
    # ``.train()``. Also note that -1100 is not a good episode return for
    # Pendulum-v1, we are using it here to shorten the experiment time.
    run_config=train.RunConfig(
        storage_path=f"file://{abs_path}",  # local saving directory
        name="PPO_Pendulum_Experiment",    # 
        stop={"env_runners/episode_return_mean": -1100.0},
    ),
)
# Run the Tuner and capture the results.
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-08-04 21:12:33</td></tr>
# <tr><td>Running for: </td><td>00:04:28.43        </td></tr>
# <tr><td>Memory:      </td><td>10.1/15.3 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 3.0/16 CPUs, 0/2 GPUs (0.0/1.0 accelerator_type:P1000)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc                 </th><th style="text-align: right;">    lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  num_training_step_ca
# lls_per_iteration</th><th style="text-align: right;">      num_env_steps_sample
# d_lifetime</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_Pendulum-v1_0ed13_00000</td><td>TERMINATED</td><td>10.110.34.88:3183870</td><td style="text-align: right;">0.001 </td><td style="text-align: right;">    17</td><td style="text-align: right;">        256.716 </td><td style="text-align: right;">1</td><td style="text-align: right;">68000</td></tr>
# <tr><td>PPO_Pendulum-v1_0ed13_00001</td><td>TERMINATED</td><td>10.110.34.88:3183871</td><td style="text-align: right;">0.0005</td><td style="text-align: right;">     3</td><td style="text-align: right;">         50.8424</td><td style="text-align: right;">1</td><td style="text-align: right;">12000</td></tr>
# <tr><td>PPO_Pendulum-v1_0ed13_00002</td><td>TERMINATED</td><td>10.110.34.88:3183872</td><td style="text-align: right;">0.0001</td><td style="text-align: right;">     4</td><td style="text-align: right;">         65.1553</td><td style="text-align: right;">1</td><td style="text-align: right;">16000</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2025-08-04 21:12:33,370	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/robotarm/data/Ray_Tutorial/checkpoints/PPO_Pendulum_Experiment' in 0.0275s.
# 2025-08-04 21:12:33,890	INFO tune.py:1041 -- Total run time: 268.96 seconds (268.40 seconds for the tuning loop).

# %%
best_checkpoint = results.get_best_result(
    metric="env_runners/episode_return_mean",
    mode="max"  # maximum reward
)

# Get the best checkpoint corresponding to the best result
# from the preceding experiment.
print("best_checkpoints: ", best_checkpoint)
# Out:
# best_checkpoints:  Result(
#   metrics={'timers': {'training_iteration': 16.730737225361874, 'restore_env_runners': 4.772419527650345e-05, 'training_step': 16.73012513332691, 'env_runner_sampling_timer': 4.186174309930475, 'learner_update_timer': 12.539987718354029, 'synch_weights': 0.003198508155695046, 'synch_env_connectors': 0.00342173548793653}, 'env_runners': {'env_to_module_sum_episodes_length_in': np.float64(131.73765420742725), 'env_to_module_sum_episodes_length_out': np.float64(131.73765420742725), 'module_to_env_connector': {'timers': {'connectors': {'tensor_to_numpy': np.float64(9.014953726898591e-05), 'remove_single_ts_time_rank_from_batch': np.float64(3.406815096758622e-06), 'get_actions': np.float64(0.0003605052017329991), 'normalize_and_clip_actions': np.float64(9.72058707174931e-05), 'un_batch_to_individual_items': np.float64(3.085118661835977e-05), 'listify_data_for_vector_env': np.float64(5.314183380117411e-05)}}, 'connector_pipeline_timer': np.float64(0.0008184579166221478)}, 'num_module_steps_sampled_lifetime': {'default_policy': 16000.0}, 'env_to_module_connector': {'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(1.5994974817568206e-05), 'numpy_to_tensor': np.float64(6.466329625281431e-05), 'batch_individual_items': np.float64(3.32538260802029e-05), 'add_time_dim_to_batch_and_zero_pad': np.float64(1.4366516368446682e-05), 'add_states_from_episodes_to_batch': np.float64(8.772350050949832e-06)}}, 'connector_pipeline_timer': np.float64(0.000259026714688057)}, 'env_reset_timer': np.float64(0.0007346089696511626), 'num_env_steps_sampled': 4000.0, 'module_episode_return_mean': {'default_policy': -1086.318255406216}, 'agent_episode_return_mean': {'default_agent': -1086.318255406216}, 'episode_duration_sec_mean': 0.37950670964550226, 'rlmodule_inference_timer': np.float64(0.00033477312051790416), 'episode_len_max': 200, 'num_agent_steps_sampled_lifetime': {'default_agent': 16000.0}, 'episode_len_mean': 200.0, 'sample': np.float64(4.090882832913831), 'num_module_steps_sampled': {'default_policy': 4000.0}, 'num_env_steps_sampled_lifetime': 16000.0, 'num_episodes': 20.0, 'num_agent_steps_sampled': {'default_agent': 4000.0}, 'episode_len_min': 200, 'episode_return_mean': -1086.318255406216, 'episode_return_max': -745.4510234841997, 'weights_seq_no': 3.0, 'episode_return_min': -1514.989774180261, 'num_episodes_lifetime': 80.0, 'env_step_timer': np.float64(0.00012244299577514323), 'time_between_sampling': np.float64(12.756412145160244), 'num_env_steps_sampled_lifetime_throughput': np.float64(477.0843844895489)}, 'learners': {'__all_modules__': {'learner_connector_sum_episodes_length_out': 4020.0, 'num_module_steps_trained_lifetime': 482816, 'learner_connector': {'timers': {'connectors': {'add_one_ts_to_episodes_and_truncate': 0.014686375839234562, 'general_advantage_estimation': 0.04284579066524294, 'add_observations_from_episodes_to_batch': 0.0006151933149517281, 'add_columns_from_episodes_to_train_batch': 0.13119160236002145, 'numpy_to_tensor': 0.00040493036333413336, 'add_time_dim_to_batch_and_zero_pad': 3.7025257008732295e-05, 'batch_individual_items': 0.2461423734411454, 'add_states_from_episodes_to_batch': 1.203403846092988e-05}}, 'connector_pipeline_timer': 0.4371240051133028}, 'num_non_trainable_parameters': 0, 'num_module_steps_trained': 120704, 'num_env_steps_trained': 3790860, 'num_env_steps_trained_lifetime': 15163440, 'num_trainable_parameters': 134403, 'learner_connector_sum_episodes_length_in': 4000.0, 'num_env_steps_trained_lifetime_throughput': 308453.3686196562, 'num_module_steps_trained_throughput': 9822.840822707258, 'num_module_steps_trained_lifetime_throughput': 9822.372770447035}, 'default_policy': {'vf_explained_var': np.float32(0.015621245), 'entropy': np.float32(1.4339349), 'num_module_steps_trained': 120704, 'vf_loss': np.float32(9.690165), 'num_trainable_parameters': 134403, 'mean_kl_loss': np.float32(0.011833318), 'total_loss': np.float32(9.764125), 'curr_entropy_coeff': 0.0, 'curr_kl_coe ...
#   path='/home/robotarm/data/Ray_Tutorial/checkpoints/PPO_Pendulum_Experiment/PPO_Pendulum-v1_0ed13_00002_2_lr=0.0001_2025-08-04_21-08-04',
#   filesystem='local',
#   checkpoint=Checkpoint(filesystem=local, path=/home/robotarm/data/Ray_Tutorial/checkpoints/PPO_Pendulum_Experiment/PPO_Pendulum-v1_0ed13_00002_2_lr=0.0001_2025-08-04_21-08-04/checkpoint_000000)
# )

# %% [markdown]
# 部署训练好的模型。从 checkpoints 创建新的模型实例并在强化学习环境中运行一个 episode 的推理

# %%
from pathlib import Path
import gymnasium as gym
import numpy as np
import torch
from ray.rllib.core.rl_module import RLModule

# Create only the neural network (RLModule) from our algorithm checkpoint.
# See here (https://docs.rayai.org.cn/en/master/rllib/checkpoints.html)
# to learn more about checkpointing and the specific "path" used.
rl_module = RLModule.from_checkpoint(
    Path(best_checkpoint.path)
    / "checkpoint_000000"
    / "learner_group"
    / "learner"
    / "rl_module"
    / "default_policy"
)
# if the python file is running, you can use the following get_module() to get RLModule
# rl_module = ppo.get_module("default_policy")  # Equivalent to `rl_module = ppo.get_module()`

# Create the RL environment to test against (same as was used for training earlier).
env = gym.make("Pendulum-v1", render_mode="human")

episode_return = 0.0
done = False

# Reset the env to get the initial observation.
obs, info = env.reset()

while not done:
    # Uncomment this line to render the env.
    # env.render()

    # Compute the next action from a batch (B=1) of observations.
    obs_batch = torch.from_numpy(obs).unsqueeze(0)  # add batch B=1 dimension
    model_outputs = rl_module.forward_inference({"obs": obs_batch})

    # Extract the action distribution parameters from the output and dissolve batch dim.
    action_dist_params = model_outputs["action_dist_inputs"][0].numpy()

    # We have continuous actions -> take the mean (max likelihood).
    greedy_action = np.clip(
        action_dist_params[0:1],  # 0=mean, 1=log(stddev), [0:1]=use mean, but keep shape=(1,)
        a_min=env.action_space.low[0],
        a_max=env.action_space.high[0],
    )
    # For discrete actions, you should take the argmax over the logits:
    # greedy_action = np.argmax(action_dist_params)

    # Send the action to the environment for the next step.
    obs, reward, terminated, truncated, info = env.step(greedy_action)

    # Perform env-loop bookkeeping.
    episode_return += reward
    done = terminated or truncated

print(f"Reached episode return of {episode_return}.")
# Out:
# Reached episode return of -987.1930495822006.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
